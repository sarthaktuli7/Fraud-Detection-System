# %% [markdown]
# # Fraud Detection Model Development
#
# This notebook demonstrates the complete machine learning pipeline for fraud detection:
#
# 1. **Data Generation & Loading**
# 2. **Advanced Feature Engineering**
# 3. **Individual Model Training & Evaluation**
# 4. **Ensemble Model Development**
# 5. **Model Explainability with SHAP**
# 6. **Performance Analysis & Visualization**
# 7. **Model Persistence**
#
# ---
#
# **Author**: Sarthak Tuli
# **Date**: January 2026
# **Objective**: Build production-ready fraud detection system with 95%+ accuracy

# %% [markdown]
# ## 🚀 1. Setup and Data Loading

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from datetime import datetime

# Suppress warnings for cleaner output
warnings.filterwarnings('ignore')

# Set plotting style
plt.style.use('default')
sns.set_palette('husl')
plt.rcParams['figure.figsize'] = (12, 8)

print("✅ Libraries imported successfully!")
print(f"📅 Training started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ✅ Libraries imported successfully!
# 📅 Training started at: 2026-01-08 14:29:09

# %%
# Import custom modules
import sys
import os
sys.path.append('../src')

from data_processing.generate_data import create_fraud_dataset
from data_processing.feature_engineering import AdvancedFeatureEngineering
from models.fraud_detector import (
    RandomForestDetector, 
    XGBoostDetector, 
    LogisticRegressionDetector,
    EnsembleFraudDetector
)

print("✅ Custom modules imported successfully!")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 6
#       3 import os
#       4 sys.path.append('../src')
# ----> 6 from data_processing.generate_data import create_fraud_dataset
#       7 from data_processing.feature_engineering import AdvancedFeatureEngineering
#       8 from models.fraud_detector import (
#       9     RandomForestDetector,
#      10     XGBoostDetector,
#      11     LogisticRegressionDetector,
#      12     EnsembleFraudDetector
#      13 )
#
# File ~\OneDrive\Desktop\fraud-detection-system\notebooks\../src\data_processing\__init__.py:8
#       1 """
#       2 Data Processing Module
#       3
#       4 Contains data generation and feature engineering utilities for fraud detection.
#       5 """
#       7 from .feature_engineering import AdvancedFeatureEngineering
# ----> 8 from .generate_data import create_fraud_dataset
#      10 __all__ = ["create_fraud_dataset", "AdvancedFeatureEngineering"]
#      11 __version__ = "1.0.0"
#
# ImportError: cannot import name 'create_fraud_dataset' from 'data_processing.generate_data' (C:\Users\sarthak\OneDrive\Desktop\fraud-detection-system\notebooks\../src\data_processing\generate_data.py)

# %%
# Generate synthetic fraud dataset
print("🔄 Creating synthetic fraud dataset...")

# Create a substantial dataset for training
DATASET_SIZE = 50000  # Increase for more robust training

df = create_fraud_dataset(n_samples=DATASET_SIZE)

print(f"📊 Dataset created with {len(df):,} transactions")
print(f"🎯 Fraud rate: {df['Class'].mean():.4f} ({df['Class'].mean()*100:.2f}%)")
print(f"💰 Average transaction amount: ${df['Amount'].mean():.2f}")

# Display basic statistics
print("\n📈 Dataset Overview:")
display(df.describe())
display(df.head())

# %% [markdown]
# ## 🔧 2. Advanced Feature Engineering

# %%
# Initialize feature engineering pipeline
print("🔧 Initializing advanced feature engineering pipeline...")

fe_pipeline = AdvancedFeatureEngineering(target_column='Class')

# Apply comprehensive feature engineering
df_engineered = fe_pipeline.fit_transform(df)

print(f"\n📊 Feature Engineering Results:")
print(f"Original features: {df.shape[1]}")
print(f"Engineered features: {df_engineered.shape[1]}")
print(f"Features added: {df_engineered.shape[1] - df.shape[1]}")

# Show feature engineering summary
feature_summary = fe_pipeline.get_feature_importance_summary()
print(f"\n🎯 Selected features: {feature_summary['total_features_created']}")
print(f"📝 Encoders fitted: {len(feature_summary['encoders_fitted'])}")
print(f"📏 Scalers fitted: {len(feature_summary['scalers_fitted'])}")
# Out:
# 🔧 Initializing advanced feature engineering pipeline...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 # Initialize feature engineering pipeline
#       2 print("🔧 Initializing advanced feature engineering pipeline...")
# ----> 4 fe_pipeline = AdvancedFeatureEngineering(target_column='Class')
#       6 # Apply comprehensive feature engineering
#       7 df_engineered = fe_pipeline.fit_transform(df)
#
# NameError: name 'AdvancedFeatureEngineering' is not defined

# %% [markdown]
# ## 🤖 3. Individual Model Training

# %%
# Prepare features and target
X = df_engineered.drop('Class', axis=1)
y = df_engineered['Class']

print(f"🎯 Final dataset for training:")
print(f"Features (X): {X.shape}")
print(f"Target (y): {y.shape}")
print(f"Class distribution: {dict(y.value_counts())}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Prepare features and target
# ----> 2 X = df_engineered.drop('Class', axis=1)
#       3 y = df_engineered['Class']
#       5 print(f"🎯 Final dataset for training:")
#
# NameError: name 'df_engineered' is not defined

# %% [markdown]
# ## 🎯 4. Ensemble Model Training

# %%
# Train ensemble model
print("🎯 Training Ensemble Fraud Detector...")

ensemble = EnsembleFraudDetector(random_state=42)
ensemble.train(X, y, test_size=0.2, balance_data=True)

print(f"\n✅ Ensemble training completed!")
print(f"🎯 Ensemble F1 Score: {ensemble.ensemble_metrics['f1_score']:.4f}")
print(f"🎯 Ensemble ROC-AUC: {ensemble.ensemble_metrics['roc_auc']:.4f}")
# Out:
# 🎯 Training Ensemble Fraud Detector...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 # Train ensemble model
#       2 print("🎯 Training Ensemble Fraud Detector...")
# ----> 4 ensemble = EnsembleFraudDetector(random_state=42)
#       5 ensemble.train(X, y, test_size=0.2, balance_data=True)
#       7 print(f"\n✅ Ensemble training completed!")
#
# NameError: name 'EnsembleFraudDetector' is not defined

# %% [markdown]
# ## 💾 5. Model Persistence

# %%
# Save trained models
import os
import joblib

os.makedirs('../models', exist_ok=True)

# Save feature engineering pipeline
joblib.dump(fe_pipeline, '../models/feature_engineering_pipeline.pkl')

# Save ensemble model
ensemble.save_ensemble('../models/fraud_detection_ensemble.pkl')

print("✅ All models saved successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 8
#       5 os.makedirs('../models', exist_ok=True)
#       7 # Save feature engineering pipeline
# ----> 8 joblib.dump(fe_pipeline, '../models/feature_engineering_pipeline.pkl')
#      10 # Save ensemble model
#      11 ensemble.save_ensemble('../models/fraud_detection_ensemble.pkl')
#
# NameError: name 'fe_pipeline' is not defined

# %% [markdown]
# ## 📊 6. Final Results

# %%
# Print final summary
print("🎯 FRAUD DETECTION MODEL TRAINING COMPLETE!")
print(f"📊 Dataset: {len(df):,} transactions")
print(f"🎯 Final Performance:")
for metric, value in ensemble.ensemble_metrics.items():
    print(f"  • {metric.replace('_', ' ').title()}: {value:.4f}")
print("🚀 Ready for production deployment!")
# Out:
# 🎯 FRAUD DETECTION MODEL TRAINING COMPLETE!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Print final summary
#       2 print("🎯 FRAUD DETECTION MODEL TRAINING COMPLETE!")
# ----> 3 print(f"📊 Dataset: {len(df):,} transactions")
#       4 print(f"🎯 Final Performance:")
#       5 for metric, value in ensemble.ensemble_metrics.items():
#
# NameError: name 'df' is not defined
